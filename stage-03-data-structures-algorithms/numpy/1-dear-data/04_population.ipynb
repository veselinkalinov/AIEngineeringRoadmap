# %%
import numpy as np

# %%
varna_population = np.array([336505, 336216, 332394, 310664, 311093, 318922, 320837, 322683])
print(varna_population[-1], varna_population[0])

diff = varna_population[-1] - varna_population[0]
print(f"Varna population changed from 2013 with {abs(diff)} people")

covid_population = varna_population[1:4]
print(f"Varna population from 2019 to 2022: {covid_population}")
# Out:
# 322683 336505
# Varna population changed from 2013 with 13822 people
# Varna population from 2019 to 2022: [336216 332394 310664]
