# %%
import numpy as np

# %%
# NumPy Funcs

# %%
# .min() Return the minimum value of an array.
# .max() Return the maximum value of an array.
# .sum() Return the total sum of an array's values.
# .average() Return the average value of an array.

# %%
temperatures = np.array(
    [[50, 51, 54, 59, 59, 53, 54, 51],
     [45, 50, 38, 44, 40, 46, 43, 39]]
)

print(np.sum(temperatures, axis=0))  # Sum of each column
print(np.min(temperatures, axis=1))  # Min of each row
# Out:
# [ 95 101  92 103  99  99  97  90]
# [50 38]

# %%
steps = np.array([10000, 5000, 7000, 2000, 4000, 12000, 4000])
print(np.min(steps))
print(np.max(steps))
print(np.sum(steps))
print(round(np.average(steps), 2))
# Out:
# 2000
# 12000
# 44000
# 6285.71
